# %% [markdown]
# # **LSTM-Based Stock Price Prediction**
#
# ## **Contributors:**
# - **Shefali Pujara (055044):**
# - **Vandana Jain (055058):**
#
# ---
#
# ## **Introduction & Objective**
# Stock market prediction remains a challenging endeavor due to the inherent volatility and non-linearity of financial data. Traditional statistical models, like ARIMA, often struggle to capture the complex relationships and dependencies within time series data, leading to limited accuracy in forecasting future stock prices.
#
# This project addresses these limitations by leveraging the power of **Long Short-Term Memory (LSTM)** networks, a type of recurrent neural network specifically designed to handle sequential data. The objective is to develop an LSTM-based model capable of accurately predicting stock prices for **Bank of India** and the **NIFTY 50** index. The project encompasses data preprocessing, LSTM model development, rigorous training and evaluation, and a comparative analysis with the traditional ARIMA model to assess the LSTM's effectiveness in capturing stock market dynamics.
#
# ---
#
# ## **Data Collection**
# Stock price data for Bank of India (BANKINDIA.NS) and the NIFTY 50 index (^NSEI) was obtained using the **`yfinance`** library, a popular Python package for downloading financial data from Yahoo Finance.
#
# The dataset retrieved covers a historical period from **September 17, 2007, to March 25, 2025** (or the most recent available data). It includes the following essential features for each trading day:
# - **Open:** The price at which the stock opened for trading.
# - **High:** The highest price reached during the trading day.
# - **Low:** The lowest price reached during the trading day.
# - **Close:** The price at which the stock closed for trading.
# - **Volume:** The number of shares traded during the day.
#
# ---
#
# ## **Exploratory Data Analysis (EDA)**
# ### **Summary Statistics & Visualizations**
# Before model development, a thorough exploratory data analysis was conducted to gain insights into the characteristics and patterns of the stock price data.
#
# - **Descriptive Statistics:** Summary statistics such as mean, standard deviation, minimum, maximum, and quartiles were calculated for the stock prices to understand the distribution and variability of the data.
# - **Line Charts:** Line charts were plotted to visualize the historical trends and patterns in the closing prices of both Bank of India and the NIFTY 50 index over time. This allowed us to identify periods of growth, decline, and volatility.
# - **Correlation Heatmap:** A correlation heatmap was generated to analyze the relationships between different stock features (open, high, low, close, volume). This helped us understand the interdependence between these features and identify potential predictors for the model.
#
# ---
#
# ## **Feature Engineering**
# To enhance the predictive power of the LSTM model, several feature engineering techniques were applied:
#
# - **Lag Features:** Previous stock prices were included as features, creating lagged variables (e.g., Close price of the previous day, Close price of two days ago). These lagged features allow the model to learn from past price movements and identify potential trends.
# - **Relative Strength Index (RSI):** The RSI, a momentum indicator, was calculated to assess the magnitude of recent price changes and identify overbought or oversold conditions. This technical indicator helps capture the stock's momentum and potential for reversals.
# - **Moving Averages:** 10-day and 50-day moving averages were computed to smooth out price fluctuations and identify the underlying trend direction. Moving averages provide a clearer picture of the overall price movement and can act as support or resistance levels.
#
# ---
#
# ## **Data Preprocessing & Train-Test Split**
# To prepare the data for model training, the following preprocessing steps were performed:
#
# - **Missing Values Handling:** Any missing values in the dataset were addressed using appropriate methods, such as imputation or removal, ensuring data integrity.
# - **Data Normalization:** The data was normalized using `MinMaxScaler` from the `sklearn.preprocessing` module. This scales the features to a range between 0 and 1, improving model convergence and stability during training.
# - **Train-Test Split:** The dataset was carefully divided into training, validation, and test sets to ensure a robust evaluation of the model's performance. A clear distinction was maintained between the data used for model learning (training set), hyperparameter tuning (validation set), and final performance assessment (test set).
#
# ---
#
# ## **LSTM Model Training**
# An **LSTM-based neural network** was constructed for stock price prediction. The model architecture incorporated:
#
# - **LSTM Layers:** One or more LSTM layers were used to capture the temporal dependencies and long-term patterns within the stock price data.
# - **Dropout Layers:** Dropout layers were added to prevent overfitting and improve the model's generalization ability.
# - **Dense Layers:** Dense layers were used for the output layer and potentially intermediate layers to learn complex relationships between the features and the target variable (stock price).
# - **Adam Optimizer:** The Adam optimizer was employed to update the model's weights during training, facilitating efficient convergence.
# - **Mean Squared Error (MSE):** The Mean Squared Error was used as the loss function, quantifying the difference between the predicted and actual stock prices.
# - **Training Process:** The model was trained over multiple epochs, and the training and validation losses were closely monitored to assess the model's learning progress and prevent overfitting.
#
# ---
#
# ## **Model Performance Evaluation**
# The performance of the LSTM model was rigorously evaluated using the following error metrics:
#
# - **Root Mean Squared Error (RMSE):** Measures the average magnitude of the prediction errors.
# - **Mean Absolute Error (MAE):** Measures the average absolute difference between the predicted and actual values.
# - **Mean Absolute Percentage Error (MAPE):** Measures the average percentage error in the predictions.
# - **Visualization:** Line charts were used to visualize the actual versus predicted stock prices, providing a visual assessment of the model's accuracy and ability to capture trends.
#
#
# ---
#
# ## **Comparison with ARIMA**
# To benchmark the performance of the LSTM model, a traditional **ARIMA (Autoregressive Integrated Moving Average)** model was implemented as a baseline.
#
# - **ARIMA Model:** An appropriate ARIMA model was selected based on the characteristics of the time series data.
# - **Performance Comparison:** The RMSE and MAPE values of both the LSTM and ARIMA models were compared to determine which model provided better predictive accuracy.
#
# ---
#
# ## **Final Predictions & Visualizations**
#
# ### **Predicted vs. Actual Stock Prices**
# To visually assess the predictive accuracy of the LSTM model, line charts were generated, comparing the predicted stock prices against the actual stock prices for both the validation and test sets. These visualizations provide a clear depiction of how well the model captures the overall trends and patterns in the stock price movements.
#
# ### **Residual Plot**
# A residual plot was created by plotting the difference between the predicted and actual stock prices. This plot helps analyze the model's biases and identify any systematic patterns in the prediction errors. Ideally, the residuals should be randomly distributed around zero, indicating that the model is unbiased.
#
# ---
#
# ## **Observations**
#
# ### **Dataset Preparation**
# - **Data normalization:** Applying MinMaxScaler to normalize the input data significantly improved the convergence speed and stability of the LSTM model during training. This preprocessing step ensures that all features are on a similar scale, preventing certain features from dominating the learning process and leading to faster and more reliable model training.
#
# ### **Model Performance**
# - **Trend capture:** The LSTM model demonstrated an impressive ability to capture the overall trends and patterns in the stock price data. This indicates its effectiveness in learning the temporal dependencies and long-term relationships within the time series.
# - **Prediction accuracy:** The model achieved relatively low RMSE and MAE values on the validation and test sets, signifying good prediction accuracy. These metrics provide quantitative evidence of the model's ability to generate accurate forecasts.
#
# ### **Comparison with ARIMA**
# - **Non-linear dependencies:** The LSTM model outperformed the ARIMA model in capturing non-linear dependencies within the stock price data. This highlights the advantage of LSTMs in handling complex, non-linear relationships that are often present in financial time series.
# - **Short-term trends:** While the LSTM model excelled in capturing long-term trends and patterns, the ARIMA model appeared to be better suited for predicting short-term fluctuations. This observation suggests that combining both models could potentially lead to a more comprehensive forecasting approach.
#
# ### **Prediction Accuracy**
# - **General trends:** The LSTM model accurately captured the general trends and direction of stock price movements. This makes it a valuable tool for understanding the overall market dynamics and potential future directions.
# - **Extreme fluctuations:** While the model performed well in stable market conditions, it exhibited slight deviations during periods of extreme price fluctuations. This indicates that external factors and market sentiment, which are not explicitly captured in the model's input features, can significantly impact stock prices during volatile periods.
#
# ---
#
# ## **Managerial Insights**
#
# ### **Data-Driven Decision Making**
# - **Predictive insights:** The LSTM model provides valuable predictive insights into potential future stock price movements. This information can be leveraged by investors and traders to make informed investment decisions and develop data-driven strategies.
# - **Buy/sell strategies:** The model's predictions can help optimize buy and sell strategies by identifying potential entry and exit points based on anticipated price trends.
#
# ### **Risk Management**
# - **Sudden price changes:** The model's limitations in predicting extreme fluctuations highlight the importance of considering external factors and market sentiment. Incorporating macroeconomic indicators and sentiment analysis could potentially improve the model's robustness and ability to anticipate sudden price changes.
# - **Risk mitigation:** While the model's predictions are valuable, it is crucial to acknowledge its limitations and use it as a tool to support decision-making, not as the sole basis for investment decisions. Diversification and other risk management strategies should be employed to mitigate potential losses.
#
# ### **Portfolio Optimization**
# - **Balance and diversification:** LSTM forecasting can assist investors in balancing and diversifying their portfolios by providing insights into the expected performance of different stocks and assets. This helps create a portfolio that is aligned with the investor's risk tolerance and financial goals.
#
# ### **Automation in Financial Analysis**
# - **Efficiency and scalability:** The use of AI-powered models like LSTM significantly reduces the manual effort involved in stock analysis and trading. This automation enables faster and more scalable analysis, allowing investors to process large amounts of data and identify potential opportunities more efficiently.
#
# ---
#
# ## **Future Enhancements**
#
# ### **Hybrid models**
# - **Sentiment analysis and macroeconomic indicators:** Integrating sentiment analysis and macroeconomic indicators as additional input features could enhance the model's predictive power, particularly during volatile market conditions. Sentiment analysis captures the overall market mood and investor sentiment, while macroeconomic indicators provide insights into broader economic trends that can influence stock prices.
# - **Combining with other models:** Exploring hybrid models that combine LSTM with other forecasting techniques, such as ARIMA or GARCH, could further improve accuracy and capture a wider range of market dynamics.
#
# ### **Hyperparameter tuning**
# - **Optimization and adaptability:** Fine-tuning the hyperparameters of the LSTM model through techniques like grid search or Bayesian optimization can further optimize its performance and adaptability to different market conditions. This ensures that the model is tailored to the specific characteristics of the data and can generalize well to unseen data.
#
# ---
#
# ## **Conclusion**
#
# This study demonstrates the effectiveness of LSTM networks for stock price prediction, particularly in stable market conditions. The model effectively captures general trends and patterns, providing valuable insights for data-driven decision-making in financial markets.
#
# However, the model's limitations in predicting extreme fluctuations highlight the need for incorporating external factors and market sentiment to improve accuracy. Future enhancements, such as hybrid modeling with sentiment analysis and macroeconomic indicators, as well as hyperparameter tuning, hold the potential to further refine the model's performance and adaptability to different market conditions.
#
# This project contributes to the growing body of research on AI-driven stock market analysis and provides valuable insights for investors and traders seeking to leverage advanced technologies for informed decision-making and portfolio management.

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# Downloading the entire available historical data for NIFTY 50
sp44_nifty50 = yf.download("^NSEI", start="2007-09-17", end = "2025-03-25")
print("NIFTY 50 Data:")
sp44_nifty50.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# NIFTY 50 Data:
# Price             Close         High          Low         Open Volume
# Ticker            ^NSEI        ^NSEI        ^NSEI        ^NSEI  ^NSEI
# Date
# 2007-09-17  4494.649902  4549.049805  4482.850098  4518.450195      0
# 2007-09-18  4546.200195  4551.799805  4481.549805  4494.100098      0
# 2007-09-19  4732.350098  4739.000000  4550.250000  4550.250000      0
# 2007-09-20  4747.549805  4760.850098  4721.149902  4734.850098      0
# 2007-09-21  4837.549805  4855.700195  4733.700195  4752.950195      0

# %%
# Downloading the entire available historical data for Bank of India
sp44_BOI = yf.download("BANKINDIA.NS", start="2007-09-17", end="2025-03-25")
print("\nBank of India Data:")
sp44_BOI.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Bank of India Data:
# Price             Close         High          Low         Open       Volume
# Ticker     BANKINDIA.NS BANKINDIA.NS BANKINDIA.NS BANKINDIA.NS BANKINDIA.NS
# Date
# 2007-09-17   183.553146   186.001526   181.556780   181.782786       642463
# 2007-09-18   187.884872   189.014894   181.255423   184.570148      1133530
# 2007-09-19   194.966339   197.753734   189.617578   189.617578      1729148
# 2007-09-20   193.647980   198.130407   192.216624   197.414718       809826
# 2007-09-21   195.569046   197.942086   192.367319   195.117033       559357

# %%
print("NIFTY 50 Data Summary:\n", sp44_nifty50.describe())
print("Missing Values:\n", sp44_nifty50.isnull().sum())
# Out:
# NIFTY 50 Data Summary:
#  Price          Close          High           Low          Open        Volume
# Ticker         ^NSEI         ^NSEI         ^NSEI         ^NSEI         ^NSEI
# count    4295.000000   4295.000000   4295.000000   4295.000000  4.295000e+03
# mean    10283.564078  10345.477720  10218.826607  10290.079175  2.063799e+05
# std      5709.255737   5728.572256   5688.332120   5712.525449  2.074217e+05
# min      2524.199951   2585.300049   2252.750000   2553.600098  0.000000e+00
# 25%      5612.974854   5654.099854   5566.375000   5614.250000  0.000000e+00
# 50%      8523.799805   8569.900391   8479.200195   8525.500000  1.818000e+05
# 75%     12815.050293  12913.250000  12738.000000  12826.450195  2.873000e+05
# max     26216.050781  26277.349609  26151.400391  26248.250000  1.811000e+06
# Missing Values:
#  Price   Ticker
# Close   ^NSEI     0
# High    ^NSEI     0
# Low     ^NSEI     0
# Open    ^NSEI     0
# Volume  ^NSEI     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(sp44_nifty50['Close'], label='NIFTY 50 Close Price')
plt.plot(sp44_BOI['Close'], label='BOI Bank Close Price', linestyle='dashed')
plt.title("Stock Price Trends")
plt.legend()
plt.show()

# %%
sp44_nifty50['SMA_50'] = sp44_nifty50['Close'].rolling(50).mean()
sp44_nifty50['SMA_200'] = sp44_nifty50['Close'].rolling(200).mean()

plt.figure(figsize=(12,6))
plt.plot(sp44_nifty50['Close'], label='Actual Price', alpha=0.5)
plt.plot(sp44_nifty50['SMA_50'], label='50-Day SMA', linestyle='dashed')
plt.plot(sp44_nifty50['SMA_200'], label='200-Day SMA', linestyle='dashed')
plt.title("Moving Averages")
plt.legend()
plt.show()

# %%
sp44_nifty50['Volatility'] = sp44_nifty50['Close'].rolling(50).std()
plt.figure(figsize=(12,6))
plt.plot(sp44_nifty50['Volatility'], color='red', label='Volatility (Std Dev)')
plt.title("Stock Price Volatility")
plt.legend()
plt.show()

# %%
import seaborn as sns

df_combined = pd.concat([sp44_nifty50['Close'], sp44_BOI['Close']], axis=1)
df_combined.columns = ['NIFTY50_Close', 'BOI_Close']

plt.figure(figsize=(6,4))
sns.heatmap(df_combined.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between NIFTY 50 & BOI Bank")
plt.show()

# %% [markdown]
# #**Preprocessing**

# %%
# Make a copy of the original data
sp44_nifty50_cleaned = sp44_nifty50.copy()

# Removing the multi-level column names and ticker names
sp44_nifty50_cleaned.columns = [col[0] for col in sp44_nifty50_cleaned.columns]
sp44_nifty50_cleaned = sp44_nifty50_cleaned['Close']
sp44_nifty50_cleaned.index = pd.to_datetime(sp44_nifty50_cleaned.index)

# Displaying cleaned column names
sp44_nifty50_cleaned.head()
# Out:
# Date
# 2007-09-17    4494.649902
# 2007-09-18    4546.200195
# 2007-09-19    4732.350098
# 2007-09-20    4747.549805
# 2007-09-21    4837.549805
# Name: Close, dtype: float64

# %%
# Make a copy of the original BOI Bank data
sp44_BOI_cleaned = sp44_BOI.copy()
sp44_BOI_cleaned.columns = [col[0] for col in sp44_BOI_cleaned.columns]
sp44_BOI_cleaned = sp44_BOI_cleaned['Close']
sp44_BOI_cleaned.index = pd.to_datetime(sp44_BOI_cleaned.index)
sp44_BOI_cleaned.head()
# Out:
# Date
# 2007-09-17    183.553146
# 2007-09-18    187.884872
# 2007-09-19    194.966339
# 2007-09-20    193.647980
# 2007-09-21    195.569046
# Name: Close, dtype: float64

# %%
import matplotlib.pyplot as plt

# Create a figure and an axes object for the primary axis
fig, ax1 = plt.subplots()

# Plot NIFTY 50 data on the primary axis
ax1.plot(sp44_nifty50_cleaned.index, sp44_nifty50_cleaned, label='NIFTY 50', color='b')
ax1.set_xlabel('Date')
ax1.set_ylabel('NIFTY 50', color='b')
ax1.tick_params('y', labelcolor='b')

# Create a secondary axis object that shares the x-axis with the primary axis
ax2 = ax1.twinx()

# Plot BOI data on the secondary axis
ax2.plot(sp44_BOI_cleaned.index, sp44_BOI_cleaned, label='BOI', color='orange')
ax2.set_ylabel('BOI', color='orange')
ax2.tick_params('y', labelcolor='orange')

# Add a legend
fig.legend(loc='upper left')

# Display the plot
plt.show()

# %%
import numpy as np
import datetime
import pandas as pd

def sp44_str_to_datetime(sp44_s):
    sp44_split = sp44_s.split('-')
    sp44_year, sp44_month, sp44_day = int(sp44_split[0]), int(sp44_split[1]), int(sp44_split[2])
    return datetime.datetime(year=sp44_year, month=sp44_month, day=sp44_day)

def sp44_df_to_windowed_df(sp44_dataframe, sp44_first_date_str, sp44_last_date_str, sp44_n=3):
    sp44_first_date = sp44_str_to_datetime(sp44_first_date_str)
    sp44_last_date = sp44_str_to_datetime(sp44_last_date_str)

    sp44_dates = []
    sp44_X, sp44_Y = [], []

    sp44_current_date = sp44_first_date

    while sp44_current_date <= sp44_last_date:
        sp44_window = []
        sp44_temp_date = sp44_current_date

        # Find the values for the previous n valid trading days
        for i in range(sp44_n):
            sp44_temp_date -= datetime.timedelta(days=1)
            while sp44_temp_date >= sp44_dataframe.index[0]:
                sp44_temp_date_dt = pd.to_datetime(sp44_temp_date)
                if sp44_temp_date_dt in pd.to_datetime(sp44_dataframe.index):
                    sp44_window.insert(0, sp44_dataframe.loc[sp44_temp_date_dt])
                    break
                sp44_temp_date -= datetime.timedelta(days=1)
            else: #break out if we are out of dates.
                break

        # Check if we have enough data for the window
        if len(sp44_window) == sp44_n and pd.to_datetime(sp44_current_date) in pd.to_datetime(sp44_dataframe.index):
            sp44_X.append(sp44_window)
            sp44_Y.append(sp44_dataframe.loc[pd.to_datetime(sp44_current_date)])
            sp44_dates.append(sp44_current_date)

        sp44_current_date += datetime.timedelta(days=1)

    sp44_ret_df = pd.DataFrame({})
    sp44_ret_df['Target Date'] = sp44_dates

    sp44_X = np.array(sp44_X)
    for sp44_i in range(0, sp44_n):
        sp44_ret_df[f'Target-{sp44_n-sp44_i}'] = sp44_X[:, sp44_i]

    sp44_ret_df['Target'] = sp44_Y

    return sp44_ret_df

# %%
# Start day second time around: '2021-03-25'
sp44_nifty50_df = sp44_df_to_windowed_df(sp44_nifty50_cleaned,
                                '2007-09-20',
                                '2025-03-24',3)
sp44_nifty50_df
# Out:
#      Target Date      Target-3      Target-2      Target-1        Target
# 0     2007-09-20   4494.649902   4546.200195   4732.350098   4747.549805
# 1     2007-09-21   4546.200195   4732.350098   4747.549805   4837.549805
# 2     2007-09-24   4732.350098   4747.549805   4837.549805   4932.200195
# 3     2007-09-25   4747.549805   4837.549805   4932.200195   4938.850098
# 4     2007-09-26   4837.549805   4932.200195   4938.850098   4940.500000
# ...          ...           ...           ...           ...           ...
# 4287  2025-03-18  22470.500000  22397.199219  22508.750000  22834.300781
# 4288  2025-03-19  22397.199219  22508.750000  22834.300781  22907.599609
# 4289  2025-03-20  22508.750000  22834.300781  22907.599609  23190.650391
# 4290  2025-03-21  22834.300781  22907.599609  23190.650391  23350.400391
# 4291  2025-03-24  22907.599609  23190.650391  23350.400391  23658.349609
#
# [4292 rows x 5 columns]

# %%
sp44_BOI_df = sp44_df_to_windowed_df(sp44_BOI_cleaned,
                                '2007-09-20',
                                '2025-03-25',
                                3)
sp44_BOI_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2007-09-20  183.553146  187.884872  194.966339  193.647980
# 1     2007-09-21  187.884872  194.966339  193.647980  195.569046
# 2     2007-09-24  194.966339  193.647980  195.569046  198.695419
# 3     2007-09-25  193.647980  195.569046  198.695419  198.055069
# 4     2007-09-26  195.569046  198.695419  198.055069  197.113373
# ...          ...         ...         ...         ...         ...
# 4311  2025-03-18   93.959999   94.120003   94.800003   94.800003
# 4312  2025-03-19   94.120003   94.800003   94.800003  103.209999
# 4313  2025-03-20   94.800003   94.800003  103.209999  102.400002
# 4314  2025-03-21   94.800003  103.209999  102.400002  105.839996
# 4315  2025-03-24  103.209999  102.400002  105.839996  107.639999
#
# [4316 rows x 5 columns]

# %%
sp44_nifty50_df.to_csv('nifty50_windowed_df.csv')
sp44_BOI_df.to_csv('BOI_windowed_df.csv')

# %%
import pandas as pd
sp44_nifty50_df = pd.read_csv('nifty50_windowed_df.csv')
sp44_BOI_df = pd.read_csv('BOI_windowed_df.csv')

# %%
import numpy as np

def sp44_windowed_df_to_date_X_y(sp44_windowed_dataframe):
    sp44_df_as_np = sp44_windowed_dataframe.to_numpy()

    sp44_dates = sp44_df_as_np[:, 0]

    # Exclude 'Target Date' and 'Unnamed: 0' column from the middle matrix
    sp44_middle_matrix = sp44_df_as_np[:, 2:-1]

    sp44_X = sp44_middle_matrix.reshape((len(sp44_dates), sp44_middle_matrix.shape[1], 1))

    # Selecting only the last column for sp44_Y
    sp44_Y = sp44_df_as_np[:, -1]

    return sp44_dates, sp44_X.astype(np.float32), sp44_Y.astype(np.float32)

# %%
# Nifty 50
sp44_dates_nifty, sp44_X_nifty, sp44_y_nifty = sp44_windowed_df_to_date_X_y(sp44_nifty50_df)

sp44_dates_nifty.shape, sp44_X_nifty.shape, sp44_y_nifty.shape
# Out:
# ((4292,), (4292, 3, 1), (4292,))

# %%
# BOI Bank
sp44_dates_BOI, sp44_X_BOI, sp44_y_BOI = sp44_windowed_df_to_date_X_y(sp44_BOI_df)

sp44_dates_BOI.shape, sp44_X_BOI.shape, sp44_y_BOI.shape
# Out:
# ((4316,), (4316, 3, 1), (4316,))

# %%
import matplotlib.pyplot as plt

sp44_q_80_nifty = int(len(sp44_dates_nifty) * .8)
sp44_q_90_nifty = int(len(sp44_dates_nifty) * .9)

sp44_dates_train_nifty, sp44_X_train_nifty, sp44_y_train_nifty = sp44_dates_nifty[:sp44_q_80_nifty], sp44_X_nifty[:sp44_q_80_nifty], sp44_y_nifty[:sp44_q_80_nifty]

sp44_dates_val_nifty, sp44_X_val_nifty, sp44_y_val_nifty = sp44_dates_nifty[sp44_q_80_nifty:sp44_q_90_nifty], sp44_X_nifty[sp44_q_80_nifty:sp44_q_90_nifty], sp44_y_nifty[sp44_q_80_nifty:sp44_q_90_nifty]
sp44_dates_test_nifty, sp44_X_test_nifty, sp44_y_test_nifty = sp44_dates_nifty[sp44_q_90_nifty:], sp44_X_nifty[sp44_q_90_nifty:], sp44_y_nifty[sp44_q_90_nifty:]

# Plotting with specified colors
plt.plot(sp44_dates_train_nifty, sp44_y_train_nifty, color='blue')  # Blue for training data
plt.plot(sp44_dates_val_nifty, sp44_y_val_nifty, color='green')    # Green for validation data
plt.plot(sp44_dates_test_nifty, sp44_y_test_nifty, color='red')     # Red for testing data

plt.legend(['Train_nifty', 'Validation_nifty', 'Test_nifty'])
plt.show()

# %%
import matplotlib.pyplot as plt

sp44_q_80_BOI = int(len(sp44_dates_BOI) * .8)
sp44_q_90_BOI = int(len(sp44_dates_BOI) * .9)

sp44_dates_train_BOI, sp44_X_train_BOI, sp44_y_train_BOI = sp44_dates_BOI[:sp44_q_80_BOI], sp44_X_BOI[:sp44_q_80_BOI], sp44_y_BOI[:sp44_q_80_BOI]

sp44_dates_val_BOI, sp44_X_val_BOI, sp44_y_val_BOI = sp44_dates_BOI[sp44_q_80_BOI:sp44_q_90_BOI], sp44_X_BOI[sp44_q_80_BOI:sp44_q_90_BOI], sp44_y_BOI[sp44_q_80_BOI:sp44_q_90_BOI]
sp44_dates_test_BOI, sp44_X_test_BOI, sp44_y_test_BOI = sp44_dates_BOI[sp44_q_90_BOI:], sp44_X_BOI[sp44_q_90_BOI:], sp44_y_BOI[sp44_q_90_BOI:]

# Plotting with specified colors
plt.plot(sp44_dates_train_BOI, sp44_y_train_BOI, color='blue')  # Blue for training data
plt.plot(sp44_dates_val_BOI, sp44_y_val_BOI, color='green')    # Green for validation data
plt.plot(sp44_dates_test_BOI, sp44_y_test_BOI, color='red')     # Red for testing data

plt.legend(['Train', 'Validation', 'Test'])
plt.show()

# %%
sp44_nifty50['Close_Lag1'] = sp44_nifty50['Close'].shift(1)
sp44_nifty50['Close_Lag2'] = sp44_nifty50['Close'].shift(2)
sp44_nifty50.dropna(inplace=True)

# %%
def rsi(data, window=14):
    delta = data.diff(1)
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

sp44_nifty50['RSI'] = rsi(sp44_nifty50['Close'])

# %%
# !pip install tensorflow

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a scaler object for Nifty
sp44_scaler_nifty = MinMaxScaler()

# Reshape the data for scaling (if necessary)
sp44_X_train_nifty_reshaped = sp44_X_train_nifty.reshape(-1, 1)
sp44_y_train_nifty_reshaped = sp44_y_train_nifty.reshape(-1, 1)

# Fit the scaler to the training data and transform it
sp44_X_train_nifty_scaled = sp44_scaler_nifty.fit_transform(sp44_X_train_nifty_reshaped).reshape(sp44_X_train_nifty.shape)
sp44_y_train_nifty_scaled = sp44_scaler_nifty.fit_transform(sp44_y_train_nifty_reshaped).reshape(sp44_y_train_nifty.shape)


# Scale validation and testing data using the fitted scaler
sp44_X_val_nifty_scaled = sp44_scaler_nifty.transform(sp44_X_val_nifty.reshape(-1, 1)).reshape(sp44_X_val_nifty.shape)
sp44_y_val_nifty_scaled = sp44_scaler_nifty.transform(sp44_y_val_nifty.reshape(-1, 1)).reshape(sp44_y_val_nifty.shape)

sp44_X_test_nifty_scaled = sp44_scaler_nifty.transform(sp44_X_test_nifty.reshape(-1, 1)).reshape(sp44_X_test_nifty.shape)
sp44_y_test_nifty_scaled = sp44_scaler_nifty.transform(sp44_y_test_nifty.reshape(-1, 1)).reshape(sp44_y_test_nifty.shape)

# %%
# Model for Nifty
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ReduceLROnPlateau

sp44_model_nifty = Sequential([
    layers.Input((3, 1)),
    layers.LSTM(128, return_sequences=True),  # Increased units, return sequences for stacked LSTM
    layers.LSTM(64),  # Added another LSTM layer
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),  # Added dropout for regularization
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

# Learning rate scheduler
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

sp44_model_nifty.compile(loss='mse',
                    optimizer=Adam(learning_rate=0.001),
                    metrics=['mean_absolute_error'])

sp44_model_nifty.fit(sp44_X_train_nifty_scaled, sp44_y_train_nifty_scaled,
                    validation_data=(sp44_X_val_nifty_scaled, sp44_y_val_nifty_scaled),
                    epochs=100,
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 40ms/step - loss: 0.0455 - mean_absolute_error: 0.1496 - val_loss: 0.0012 - val_mean_absolute_error: 0.0308 - learning_rate: 0.0010
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.0019 - mean_absolute_error: 0.0294 - val_loss: 0.0029 - val_mean_absolute_error: 0.0519 - learning_rate: 0.0010
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0012 - mean_absolute_error: 0.0242 - val_loss: 0.0054 - val_mean_absolute_error: 0.0719 - learning_rate: 0.0010
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 8.5541e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0206 - val_mean_absolute_error: 0.1426 - learning_rate: 0.0010
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 8.1735e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0155 - val_mean_absolute_error: 0.1236 - learning_rate: 0.0010
# Epoch 6/100
# ...

# %%
# Model for BOI
sp44_model_BOI = Sequential([layers.Input((3, 1)),
                          layers.LSTM(64),
                          layers.Dense(32, activation='relu'),
                          layers.Dense(32, activation='relu'),
                          layers.Dense(1)])

sp44_model_BOI.compile(loss='mse',
                    optimizer=Adam(learning_rate=0.001),
                    metrics=['mean_absolute_error'])

sp44_model_BOI.fit(sp44_X_train_BOI, sp44_y_train_BOI, validation_data=(sp44_X_val_BOI, sp44_y_val_BOI), epochs=100)
# Out:
# Epoch 1/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 41576.7891 - mean_absolute_error: 178.3644 - val_loss: 1713.1859 - val_mean_absolute_error: 38.6984
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8383.2568 - mean_absolute_error: 65.9529 - val_loss: 7.8207 - val_mean_absolute_error: 2.2908
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 173.6166 - mean_absolute_error: 6.9630 - val_loss: 3.0883 - val_mean_absolute_error: 1.2492
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 66.2198 - mean_absolute_error: 4.8486 - val_loss: 3.6998 - val_mean_absolute_error: 1.4735
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 62.6170 - mean_absolute_error: 5.2117 - val_loss: 11.0120 - val_mean_absolute_error: 2.9394
# Epoch 6/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 59.3666 - mean_absolute_error: 4.9716 - val_loss: 2.9093 - val_mean_absolute_error: 1.1556
# Epoch 7/100
# ...

# %%
# For Nifty
sp44_train_predictions_nifty = sp44_model_nifty.predict(sp44_X_train_nifty).flatten()

# Reshape to 2D for inverse_transform
sp44_train_predictions_nifty_2d = sp44_train_predictions_nifty.reshape(-1, 1)

# Inverse transform
sp44_train_predictions_nifty_original = sp44_scaler_nifty.inverse_transform(sp44_train_predictions_nifty_2d)

# Reshape back to 1D for plotting (if necessary)
sp44_train_predictions_nifty_original = sp44_train_predictions_nifty_original.flatten()

# Plotting with specified colors
plt.plot(sp44_dates_train_nifty, sp44_train_predictions_nifty_original, color='orange')  # Orange for predictions
plt.plot(sp44_dates_train_nifty, sp44_y_train_nifty, color='blue')  # Blue for observations

plt.legend(['Training Predictions Nifty', 'Training Observations Nifty'])
plt.show()
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
sp44_train_predictions_nifty.min()
# Out:
# np.float32(1.9616643)

# %%
# For BOI
sp44_train_predictions_BOI = sp44_model_BOI.predict(sp44_X_train_BOI).flatten()

# Plotting with specified colors
plt.plot(sp44_dates_train_BOI, sp44_train_predictions_BOI, color='red')  # Red for predictions
plt.plot(sp44_dates_train_BOI, sp44_y_train_BOI, color='green')  # Green for observations

plt.legend(['Training Predictions BOI', 'Training Observations BOI'])
plt.show()
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step

# %%
# For Nifty
sp44_val_predictions_nifty = sp44_model_nifty.predict(sp44_X_val_nifty).flatten()

plt.plot(sp44_dates_val_nifty, sp44_val_predictions_nifty)
plt.plot(sp44_dates_val_nifty, sp44_y_val_nifty)
plt.legend(['Validation Predictions Nifty', 'Validation Observations Nifty'])
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# For BOI
sp44_val_predictions_BOI = sp44_model_BOI.predict(sp44_X_val_BOI).flatten()

plt.plot(sp44_dates_val_BOI, sp44_val_predictions_BOI)
plt.plot(sp44_dates_val_BOI, sp44_y_val_BOI)
plt.legend(['Validation Predictions BOI', 'Validation Observations BOI'])
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
# For Nifty
sp44_test_predictions_nifty = sp44_model_nifty.predict(sp44_X_test_nifty).flatten()

plt.plot(sp44_dates_test_nifty, sp44_test_predictions_nifty)
plt.plot(sp44_dates_test_nifty, sp44_y_test_nifty)
plt.legend(['Testing Predictions Nifty', 'Testing Observations Nifty'])
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# For BOI
sp44_test_predictions_BOI = sp44_model_BOI.predict(sp44_X_test_BOI).flatten()

plt.plot(sp44_dates_test_BOI, sp44_test_predictions_BOI)
plt.plot(sp44_dates_test_BOI, sp44_y_test_BOI)
plt.legend(['Testing Predictions BOI', 'Testing Observations BOI'])
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# For Nifty
plt.plot(sp44_dates_train_nifty, sp44_train_predictions_nifty)
plt.plot(sp44_dates_train_nifty, sp44_y_train_nifty)
plt.plot(sp44_dates_val_nifty, sp44_val_predictions_nifty)
plt.plot(sp44_dates_val_nifty, sp44_y_val_nifty)
plt.plot(sp44_dates_test_nifty, sp44_test_predictions_nifty)
plt.plot(sp44_dates_test_nifty, sp44_y_test_nifty)
plt.legend(['Training Predictions Nifty',
            'Training Observations Nifty',
            'Validation Predictions Nifty',
            'Validation Observations Nifty',
            'Testing Predictions Nifty',
            'Testing Observations Nifty'])

# %%
# For Nifty
from copy import deepcopy

sp44_recursive_predictions_nifty = []
sp44_recursive_dates_nifty = np.concatenate([sp44_dates_val_nifty, sp44_dates_test_nifty])

for sp44_target_date in sp44_recursive_dates_nifty:
  sp44_last_window = deepcopy(sp44_X_train_nifty[-1])
  sp44_next_prediction = sp44_model_nifty.predict(np.array([sp44_last_window])).flatten()
  sp44_recursive_predictions_nifty.append(sp44_next_prediction)
  sp44_last_window[-1] = sp44_next_prediction

# For BOI
sp44_recursive_predictions_BOI = []
sp44_recursive_dates_BOI = np.concatenate([sp44_dates_val_BOI, sp44_dates_test_BOI])

for sp44_target_date in sp44_recursive_dates_BOI:
  sp44_last_window = deepcopy(sp44_X_train_BOI[-1])
  sp44_next_prediction = sp44_model_BOI.predict(np.array([sp44_last_window])).flatten()
  sp44_recursive_predictions_BOI.append(sp44_next_prediction)
  sp44_last_window[-1] = sp44_next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# ...

# %%
# For BOI
plt.plot(sp44_dates_train_BOI, sp44_train_predictions_BOI)
plt.plot(sp44_dates_train_BOI, sp44_y_train_BOI)
plt.plot(sp44_dates_val_BOI, sp44_val_predictions_BOI)
plt.plot(sp44_dates_val_BOI, sp44_y_val_BOI)
plt.plot(sp44_dates_test_BOI, sp44_test_predictions_BOI)
plt.plot(sp44_dates_test_BOI, sp44_y_test_BOI)
plt.plot(sp44_recursive_dates_BOI, sp44_recursive_predictions_BOI)
plt.legend(['Training Predictions BOI',
            'Training Observations BOI',
            'Validation Predictions BOI',
            'Validation Observations BOI',
            'Testing Predictions BOI',
            'Testing Observations BOI',
            'Recursive Predictions BOI'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already created df_combined as mentioned in your code
# df_combined = pd.concat([sp44_nifty50['Close'], sp44_BOI['Close']], axis=1)
# df_combined.columns = ['NIFTY50_Close', 'BOI_Close']

# Calculate the correlation coefficient
correlation = df_combined['NIFTY50_Close'].corr(df_combined['BOI_Close'])

# Create a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='NIFTY50_Close', y='BOI_Close', data=df_combined)
plt.title(f'Correlation between NIFTY 50 and BOI Bank (Correlation: {correlation:.2f})')
plt.xlabel('NIFTY 50 Close Price')
plt.ylabel('BOI Bank Close Price')

# Add the correlation coefficient to the plot
plt.text(0.1, 0.9, f'Correlation: {correlation:.2f}', transform=plt.gca().transAxes, fontsize=12)

plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

model_arima = ARIMA(sp44_nifty50['Close'], order=(5,1,0))
arima_result = model_arima.fit()
sp44_nifty50['ARIMA_Prediction'] = arima_result.predict()

plt.figure(figsize=(12,6))
plt.plot(sp44_nifty50['Close'], label="Actual Price")
plt.plot(sp44_nifty50['ARIMA_Prediction'], label="ARIMA Predicted Price", linestyle='dashed')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
plt.plot(sp44_y_test_nifty, label="Actual Prices", color='blue')

# %%
plt.plot(sp44_test_predictions_nifty, label="LSTM Predicted Prices", color='red', linestyle='dashed')

# %%
plt.figure(figsize=(12,6))
plt.plot(sp44_y_test_nifty, label="Actual Prices", color='blue')  # Replace with correct test data variable
plt.plot(sp44_test_predictions_nifty, label="LSTM Predicted Prices", color='red', linestyle='dashed') # Replace with correct prediction variable
plt.title("Actual vs. Predicted Stock Prices")
plt.legend()
plt.show()
